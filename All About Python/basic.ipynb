# %%
## Basic syntax rules in python

## 1. Case sensitivity- python is case sensitive
## for example

name = "rahul"
Name = "rishi"

print(name)
print(Name)

## if you see both the variable seems like equal
## but it is not , as python is case sensitive.
# Out:
# rahul
# rishi

# %%
## 2. Indentation

## Python uses indentation to define blocks of code.
## Consistent use of spaces(commonly-4) or a tab is required.

## For example

age=32
if age>30:
    print(age)
print(age)


## Another example 
if True:
    print("Correct Indentation")
    if False:
        print("THis won't print")
    print("This wil print")
print("Outside the if block")        

## Unlike many other languages that use braces {} to delimit blocks
## of code, python uses identation to determine the grouping of statements.
## This means that all the statements within a block must be indented at
## the same level.

## So if you see as soon as i use colon after conditon
## and press enter , the tab comes after 4 spaces, which means that
## whatever you will write the code in this , only that will be executed
## It is just like the curly braces.
# Out:
# 32
# 32
# Correct Indentation
# This wil print
# Outside the if block

# %%
## Line Continuation

## If you are at the end of the page and want to continue to 
## to the same line , in the next line , then you can use "\".

## For example 

total=1+2+3+4+5+8+\
6+7+9+10+26

print(total)

## you cna see the code is running.
# Out:
# 81

# %%
## Multiple Statement on a single line

x=5;y=10;z=x+y
print(z)

## You can see that you can add multiple statements in a single line 
## just by using ':'
# Out:
# 15

# %%
## Uderstand sementics in python

## So in python , you don't need to mention the variable type
## kernel automatically will understand the variable type on run time.

age= 32
name="krish"

## If you run the code, it will run without any error.

## And if you want to know the type of the variable then you have to write

type(age)
# Out:
# int

# %%
## Type Inference

## kernel automatically will understand the variable type on run time.
variable= 10
print(type(variable))
variable="rishi"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>
